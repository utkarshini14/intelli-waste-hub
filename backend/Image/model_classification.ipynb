# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
import zipfile
import os

local_zip = 'waste classification.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('')
zip_ref.close()

# %%
base_dir = 'DATASET'
train_dir = os.path.join(base_dir, 'TRAIN')
validation_dir = os.path.join(base_dir, 'TEST')

train_organic_dir = os.path.join(train_dir, 'O')

train_recycle_dir = os.path.join(train_dir, 'R')

validation_organic_dir = os.path.join(validation_dir, 'O')

validation_recycle_dir = os.path.join(validation_dir, 'R')

print('total training organic images:', len(os.listdir(train_organic_dir)))
print('total training recycyle images:', len(os.listdir(train_recycle_dir)))
print('total validation organic images:', len(os.listdir(validation_organic_dir)))
print('total validation recycyle images:', len(os.listdir(validation_recycle_dir)))
# Out:
# total training organic images: 12565
# total training recycyle images: 9999
# total validation organic images: 1401
# total validation recycyle images: 1112

# %%
train_organic_fnames = os.listdir(train_organic_dir)
train_recycle_fnames = os.listdir(train_recycle_dir)
train_recycle_fnames.sort()

nrows = 2
ncols = 4

pic_index = 0


fig = plt.gcf()
fig.set_size_inches(ncols * 4, nrows *4)

pic_index += 4
next_organic_pix = [os.path.join(train_organic_dir, fname) 
                for fname in train_organic_fnames[pic_index-4:pic_index]]
next_recycle_pix = [os.path.join(train_recycle_dir, fname) 
                for fname in train_recycle_fnames[pic_index-4:pic_index]]

for i, img_path in enumerate(next_organic_pix + next_recycle_pix):
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off')

  img = mpimg.imread(img_path)
  plt.imshow(img)
  print(img.shape)

plt.show()
# Out:
# (225, 225, 3)
# (224, 224, 3)
# (191, 264, 3)
# (168, 300, 3)
# (160, 314, 3)
# (150, 300, 3)
# (187, 269, 3)
# (168, 300, 3)

# %%
from tensorflow.keras import layers
from tensorflow.keras import Model

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import RMSprop

# %%
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        train_dir,              
        target_size=(150, 150),  
        shuffle=True,
        class_mode='binary')


validation_generator = val_datagen.flow_from_directory(
        validation_dir,
        target_size=(150, 150),
        shuffle=True,
        class_mode='binary')
# Out:
# Found 22564 images belonging to 2 classes.
# Found 2513 images belonging to 2 classes.

# %%
img_input = layers.Input(shape=(150, 150, 3))
x = layers.Conv2D(16, 3, activation='relu')(img_input)
x = layers.MaxPooling2D(2)(x)
x = layers.Conv2D(32, 3, activation='relu')(x)
x = layers.MaxPooling2D(2)(x)
x = layers.Conv2D(64, 3, activation='relu')(x)
x = layers.MaxPooling2D(2)(x)
x = layers.Flatten()(x)
x = layers.Dense(512, activation='relu')(x)
x = layers.Dropout(0.5)(x)
output = layers.Dense(1, activation='sigmoid')(x)
model = Model(img_input, output)

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 150, 150, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 148, 148, 16)   │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 74, 74, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 72, 72, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 36, 36, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 34, 34, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 17, 17, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 18496)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     9,470,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9,494,561 (36.22 MB)
#  Trainable params: 9,494,561 (36.22 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.optimizers import RMSprop

# Compile the model with correct argument
model.compile(
    loss='binary_crossentropy',
    optimizer=RMSprop(learning_rate=0.001),  # ✅ Use learning_rate instead of lr
    metrics=['accuracy']  # ✅ Use 'accuracy' instead of 'acc'
)

# Train the model
history = model.fit(
    train_generator,
    epochs=500,
    validation_data=validation_generator,
    verbose=2,
    shuffle=True
)
# Out:
# Epoch 1/500
# /Users/utkarshininarayan/Desktop/projects/.venvv/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 706/706 - 71s - 101ms/step - accuracy: 0.8054 - loss: 0.4581 - val_accuracy: 0.8806 - val_loss: 0.3105
# Epoch 2/500
# 706/706 - 71s - 101ms/step - accuracy: 0.8435 - loss: 0.3753 - val_accuracy: 0.9045 - val_loss: 0.2656
# Epoch 3/500
# 706/706 - 73s - 103ms/step - accuracy: 0.8579 - loss: 0.3478 - val_accuracy: 0.9105 - val_loss: 0.2534
# Epoch 4/500
# 706/706 - 75s - 107ms/step - accuracy: 0.8683 - loss: 0.3244 - val_accuracy: 0.9093 - val_loss: 0.2471
# Epoch 5/500
# 706/706 - 77s - 109ms/step - accuracy: 0.8794 - loss: 0.2977 - val_accuracy: 0.9053 - val_loss: 0.2516
# Epoch 6/500
# 706/706 - 79s - 111ms/step - accuracy: 0.8913 - loss: 0.2720 - val_accuracy: 0.8404 - val_loss: 0.5264
# Epoch 7/500
# 706/706 - 79s - 111ms/step - accuracy: 0.9049 - loss: 0.2399 - val_accuracy: 0.8890 - val_loss: 0.3501
# Epoch 8/500
# 706/706 - 78s - 111ms/step - accuracy: 0.9204 - loss: 0.2049 - val_accuracy: 0.9089 - val_loss: 0.3184
# Epoch 9/500
# 706/706 - 80s - 113ms/step - accuracy: 0.9355 - loss: 0.1764 - val_accuracy: 0.9029 - val_loss: 0.3090
# Epoch 10/500
# 706/706 - 75s - 106ms/step - accuracy: 0.9478 - loss: 0.1411 - val_accuracy: 0.8874 - val_loss: 0.5158
# Epoch 11/500
# 706/706 - 80s - 113ms/step - accuracy: 0.9602 - loss: 0.1117 - val_accuracy: 0.8484 - val_loss: 0.9405
# Epoch 12/500
# 706/706 - 617s - 873ms/step - accuracy: 0.9665 - loss: 0.0927 - val_accuracy: 0.9065 - val_loss: 0.5563
# Epoch 13/500
# 706/706 - 546s - 774ms/step - accuracy: 0.9746 - loss: 0.0798 - val_accuracy: 0.8973 - val_loss: 0.4790
# Epoch 14/500
# 706/706 - 75s - 106ms/step - accuracy: 0.9792 - loss: 0.0672 - val_accuracy: 0.8643 - val_loss: 0.8401
# Epoch 15/500
# 706/706 - 76s - 108ms/step - accuracy: 0.9839 - loss: 0.0571 - val_accuracy: 0.8870 - val_loss: 0.7181
# Epoch 16/500
# 706/706 - 1075s - 2s/step - accuracy: 0.9850 - loss: 0.0491 - val_accuracy: 0.8930 - val_loss: 0.8636
# Epoch 17/500
# 706/706 - 75s - 106ms/step - accuracy: 0.9860 - loss: 0.0503 - val_accuracy: 0.8727 - val_loss: 1.0877
# Epoch 18/500
# 706/706 - 74s - 105ms/step - accuracy: 0.9886 - loss: 0.0428 - val_accuracy: 0.8938 - val_loss: 0.8239
# Epoch 19/500
# 706/706 - 80s - 114ms/step - accuracy: 0.9883 - loss: 0.0382 - val_accuracy: 0.8822 - val_loss: 0.9616
# Epoch 20/500
# 706/706 - 96s - 137ms/step - accuracy: 0.9890 - loss: 0.0408 - val_accuracy: 0.8747 - val_loss: 1.4681
# Epoch 21/500
# 706/706 - 92s - 131ms/step - accuracy: 0.9892 - loss: 0.0404 - val_accuracy: 0.8965 - val_loss: 1.0679
# Epoch 22/500
# 706/706 - 86s - 122ms/step - accuracy: 0.9891 - loss: 0.0436 - val_accuracy: 0.9009 - val_loss: 1.0333
# Epoch 23/500
# 706/706 - 86s - 121ms/step - accuracy: 0.9907 - loss: 0.0394 - val_accuracy: 0.8981 - val_loss: 1.1303
# Epoch 24/500
# 706/706 - 86s - 122ms/step - accuracy: 0.9908 - loss: 0.0373 - val_accuracy: 0.8814 - val_loss: 1.3494
# Epoch 25/500
# 706/706 - 475s - 673ms/step - accuracy: 0.9911 - loss: 0.0384 - val_accuracy: 0.8794 - val_loss: 1.6974
# Epoch 26/500
# 706/706 - 1288s - 2s/step - accuracy: 0.9923 - loss: 0.0323 - val_accuracy: 0.8786 - val_loss: 1.2773
# Epoch 27/500
# 706/706 - 292s - 414ms/step - accuracy: 0.9899 - loss: 0.0430 - val_accuracy: 0.9005 - val_loss: 1.1521
# Epoch 28/500
# 706/706 - 74s - 105ms/step - accuracy: 0.9914 - loss: 0.0434 - val_accuracy: 0.9061 - val_loss: 1.3865
# Epoch 29/500
# 706/706 - 74s - 105ms/step - accuracy: 0.9915 - loss: 0.0439 - val_accuracy: 0.8587 - val_loss: 1.9364
# Epoch 30/500
# 706/706 - 78s - 110ms/step - accuracy: 0.9919 - loss: 0.0365 - val_accuracy: 0.8790 - val_loss: 1.3643
# Epoch 31/500
# 706/706 - 82s - 116ms/step - accuracy: 0.9933 - loss: 0.0305 - val_accuracy: 0.8798 - val_loss: 1.3402
# Epoch 32/500
# 706/706 - 80s - 114ms/step - accuracy: 0.9906 - loss: 0.0382 - val_accuracy: 0.8786 - val_loss: 1.7683
# Epoch 33/500
# 706/706 - 80s - 114ms/step - accuracy: 0.9917 - loss: 0.0437 - val_accuracy: 0.8886 - val_loss: 1.6382
# Epoch 34/500
# 706/706 - 80s - 113ms/step - accuracy: 0.9926 - loss: 0.0416 - val_accuracy: 0.8953 - val_loss: 1.2650
# Epoch 35/500
# 706/706 - 81s - 115ms/step - accuracy: 0.9925 - loss: 0.0330 - val_accuracy: 0.8930 - val_loss: 1.5995
# Epoch 36/500
# 706/706 - 81s - 114ms/step - accuracy: 0.9935 - loss: 0.0356 - val_accuracy: 0.8790 - val_loss: 1.8033
# Epoch 37/500
# 706/706 - 78s - 111ms/step - accuracy: 0.9930 - loss: 0.0364 - val_accuracy: 0.8926 - val_loss: 1.8342
# Epoch 38/500
# 706/706 - 79s - 111ms/step - accuracy: 0.9927 - loss: 0.0424 - val_accuracy: 0.8575 - val_loss: 1.3379
# Epoch 39/500
# 706/706 - 82s - 116ms/step - accuracy: 0.9922 - loss: 0.0431 - val_accuracy: 0.8874 - val_loss: 1.7966
# Epoch 40/500
# 706/706 - 86s - 121ms/step - accuracy: 0.9930 - loss: 0.0422 - val_accuracy: 0.8659 - val_loss: 2.3932
# Epoch 41/500
# 706/706 - 89s - 126ms/step - accuracy: 0.9934 - loss: 0.0304 - val_accuracy: 0.8898 - val_loss: 1.5476
# Epoch 42/500
# 706/706 - 88s - 124ms/step - accuracy: 0.9933 - loss: 0.0378 - val_accuracy: 0.8882 - val_loss: 2.3481
# Epoch 43/500
# 706/706 - 88s - 125ms/step - accuracy: 0.9924 - loss: 0.0490 - val_accuracy: 0.8949 - val_loss: 1.4103
# Epoch 44/500
# 706/706 - 87s - 123ms/step - accuracy: 0.9922 - loss: 0.0481 - val_accuracy: 0.8882 - val_loss: 2.6636
# Epoch 45/500
# 706/706 - 85s - 120ms/step - accuracy: 0.9939 - loss: 0.0387 - val_accuracy: 0.8715 - val_loss: 2.4329
# Epoch 46/500
# 706/706 - 84s - 119ms/step - accuracy: 0.9934 - loss: 0.0375 - val_accuracy: 0.8758 - val_loss: 1.9237
# Epoch 47/500
# 706/706 - 84s - 118ms/step - accuracy: 0.9941 - loss: 0.0328 - val_accuracy: 0.8778 - val_loss: 2.4231
# Epoch 48/500
# 706/706 - 84s - 119ms/step - accuracy: 0.9945 - loss: 0.0379 - val_accuracy: 0.8818 - val_loss: 2.6367
# Epoch 49/500
# 706/706 - 1007s - 1s/step - accuracy: 0.9949 - loss: 0.0296 - val_accuracy: 0.8926 - val_loss: 2.4553
# Epoch 50/500
# 706/706 - 1256s - 2s/step - accuracy: 0.9946 - loss: 0.0400 - val_accuracy: 0.8882 - val_loss: 1.9399
# Epoch 51/500
# 706/706 - 120s - 170ms/step - accuracy: 0.9923 - loss: 0.0499 - val_accuracy: 0.9009 - val_loss: 1.9995
# Epoch 52/500
# 706/706 - 234s - 331ms/step - accuracy: 0.9938 - loss: 0.0347 - val_accuracy: 0.8818 - val_loss: 2.6778
# Epoch 53/500
# 706/706 - 128s - 181ms/step - accuracy: 0.9931 - loss: 0.0418 - val_accuracy: 0.8934 - val_loss: 1.9642
# Epoch 54/500
# 706/706 - 95s - 134ms/step - accuracy: 0.9941 - loss: 0.0377 - val_accuracy: 0.8647 - val_loss: 3.4599
# Epoch 55/500
# 706/706 - 73s - 104ms/step - accuracy: 0.9930 - loss: 0.0491 - val_accuracy: 0.8878 - val_loss: 2.5484
# Epoch 56/500
# 706/706 - 76s - 108ms/step - accuracy: 0.9942 - loss: 0.0401 - val_accuracy: 0.8750 - val_loss: 2.5646
# Epoch 57/500
# 706/706 - 87s - 124ms/step - accuracy: 0.9941 - loss: 0.0436 - val_accuracy: 0.8858 - val_loss: 2.8009
# Epoch 58/500
# 706/706 - 88s - 125ms/step - accuracy: 0.9946 - loss: 0.0390 - val_accuracy: 0.8858 - val_loss: 2.7448
# Epoch 59/500
# 706/706 - 89s - 126ms/step - accuracy: 0.9943 - loss: 0.0408 - val_accuracy: 0.8985 - val_loss: 2.3644
# Epoch 60/500
# 706/706 - 90s - 127ms/step - accuracy: 0.9949 - loss: 0.0351 - val_accuracy: 0.9049 - val_loss: 2.1786
# Epoch 61/500
# 706/706 - 95s - 134ms/step - accuracy: 0.9948 - loss: 0.0306 - val_accuracy: 0.8961 - val_loss: 2.4639
# Epoch 62/500
# 706/706 - 94s - 133ms/step - accuracy: 0.9944 - loss: 0.0423 - val_accuracy: 0.8910 - val_loss: 2.4785
# Epoch 63/500
# 706/706 - 90s - 128ms/step - accuracy: 0.9939 - loss: 0.0448 - val_accuracy: 0.8898 - val_loss: 2.7314
# Epoch 64/500
# 706/706 - 97s - 138ms/step - accuracy: 0.9940 - loss: 0.0439 - val_accuracy: 0.8942 - val_loss: 2.6388
# Epoch 65/500
# 706/706 - 98s - 139ms/step - accuracy: 0.9945 - loss: 0.0344 - val_accuracy: 0.8858 - val_loss: 3.4284
# Epoch 66/500
# 706/706 - 99s - 140ms/step - accuracy: 0.9943 - loss: 0.0419 - val_accuracy: 0.8918 - val_loss: 2.3830
# Epoch 67/500
# 706/706 - 105s - 148ms/step - accuracy: 0.9931 - loss: 0.0515 - val_accuracy: 0.8945 - val_loss: 2.7667
# Epoch 68/500
# 706/706 - 101s - 143ms/step - accuracy: 0.9948 - loss: 0.0418 - val_accuracy: 0.8882 - val_loss: 2.9508
# Epoch 69/500
# 706/706 - 98s - 138ms/step - accuracy: 0.9941 - loss: 0.0597 - val_accuracy: 0.9045 - val_loss: 2.4807
# Epoch 70/500
# 706/706 - 102s - 144ms/step - accuracy: 0.9925 - loss: 0.0609 - val_accuracy: 0.8794 - val_loss: 3.1124
# Epoch 71/500
# 706/706 - 107s - 152ms/step - accuracy: 0.9930 - loss: 0.0609 - val_accuracy: 0.8866 - val_loss: 3.4145
# Epoch 72/500
# 706/706 - 98s - 138ms/step - accuracy: 0.9961 - loss: 0.0360 - val_accuracy: 0.8926 - val_loss: 3.1549
# Epoch 73/500
# 706/706 - 102s - 144ms/step - accuracy: 0.9953 - loss: 0.0342 - val_accuracy: 0.8898 - val_loss: 3.5750
# Epoch 74/500
# 706/706 - 99s - 141ms/step - accuracy: 0.9946 - loss: 0.0386 - val_accuracy: 0.8822 - val_loss: 3.0576
# Epoch 75/500
# 706/706 - 104s - 147ms/step - accuracy: 0.9949 - loss: 0.0361 - val_accuracy: 0.9001 - val_loss: 3.1240
# Epoch 76/500
# 706/706 - 106s - 150ms/step - accuracy: 0.9954 - loss: 0.0485 - val_accuracy: 0.8898 - val_loss: 2.8447
# Epoch 77/500
# 706/706 - 108s - 153ms/step - accuracy: 0.9938 - loss: 0.0602 - val_accuracy: 0.8802 - val_loss: 3.0306
# Epoch 78/500
# 706/706 - 114s - 161ms/step - accuracy: 0.9943 - loss: 0.0500 - val_accuracy: 0.8707 - val_loss: 3.1031
# Epoch 79/500
# 706/706 - 109s - 155ms/step - accuracy: 0.9943 - loss: 0.0509 - val_accuracy: 0.8655 - val_loss: 3.7388
# Epoch 80/500
# 706/706 - 107s - 152ms/step - accuracy: 0.9955 - loss: 0.0371 - val_accuracy: 0.8870 - val_loss: 3.2017
# Epoch 81/500
# 706/706 - 108s - 153ms/step - accuracy: 0.9944 - loss: 0.0535 - val_accuracy: 0.8826 - val_loss: 3.5893
# Epoch 82/500
# 706/706 - 99s - 140ms/step - accuracy: 0.9949 - loss: 0.0420 - val_accuracy: 0.8993 - val_loss: 4.1776
# Epoch 83/500
# 706/706 - 109s - 154ms/step - accuracy: 0.9939 - loss: 0.0615 - val_accuracy: 0.8774 - val_loss: 4.1700
# Epoch 84/500
# 706/706 - 98s - 138ms/step - accuracy: 0.9943 - loss: 0.0504 - val_accuracy: 0.8898 - val_loss: 3.3420
# Epoch 85/500
# 706/706 - 94s - 133ms/step - accuracy: 0.9947 - loss: 0.0482 - val_accuracy: 0.8762 - val_loss: 4.5540
# Epoch 86/500
# 706/706 - 95s - 135ms/step - accuracy: 0.9952 - loss: 0.0461 - val_accuracy: 0.8977 - val_loss: 3.2215
# Epoch 87/500
# 706/706 - 86s - 122ms/step - accuracy: 0.9950 - loss: 0.0506 - val_accuracy: 0.8400 - val_loss: 6.3241
# Epoch 88/500
# 706/706 - 86s - 121ms/step - accuracy: 0.9944 - loss: 0.0540 - val_accuracy: 0.8699 - val_loss: 4.8745
# Epoch 89/500
# 706/706 - 89s - 126ms/step - accuracy: 0.9949 - loss: 0.0536 - val_accuracy: 0.8918 - val_loss: 3.7637
# Epoch 90/500
# 706/706 - 88s - 125ms/step - accuracy: 0.9947 - loss: 0.0475 - val_accuracy: 0.8997 - val_loss: 3.0230
# Epoch 91/500

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, label='training accuracy')
plt.plot(epochs, val_acc, label='validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()
plt.plot(epochs, loss, label='training loss')
plt.plot(epochs, val_loss, label='validation loss')
plt.title('Training and validation loss')
plt.legend()

# %%
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.optimizers import SGD

local_weights_file = 'inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5'
pre_trained_model = InceptionV3(
    input_shape=(150, 150, 3), include_top=False, weights=None)
pre_trained_model.load_weights(local_weights_file)


for layer in pre_trained_model.layers:
  layer.trainable = False


last_layer = pre_trained_model.get_layer('mixed7')
print('last layer output shape:', last_layer.output_shape)
last_output = last_layer.output

# %%
x = layers.Flatten()(last_output)
x = layers.Dense(1024, activation='relu')(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(1, activation='sigmoid')(x)
unfreeze = False
for layer in pre_trained_model.layers:
  if unfreeze:
    layer.trainable = True
  if layer.name == 'mixed6':
    unfreeze = True
model = Model(pre_trained_model.input, x)
model.compile(loss='binary_crossentropy',
              optimizer=SGD(
                  lr=0.00001, 
                  momentum=0.9),
              metrics=['acc'])

# %%
model.summary()

# %%
history = model.fit_generator(
      train_generator,
      steps_per_epoch=500,
      epochs=500,
      validation_data=validation_generator,
      validation_steps=50,
      verbose=2)

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(acc))
plt.plot(epochs, acc, label='training accuracy')
plt.plot(epochs, val_acc, label='validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, label='training loss')
plt.plot(epochs, val_loss, label='validation loss')
plt.title('Training and validation loss')
plt.legend()

# %%
val_visual = val_datagen.flow_from_directory(
        validation_dir,
        target_size=(150, 150),
        class_mode='binary',
        shuffle=True)

print(val_visual.class_indices)

# %%
val_pred_prob = model.predict(val_visual)

# %%
val_dir_indices = val_visual.index_array
val_true_labels = [0 if n < 1112 else 1 for n in val_dir_indices] 
val_pred_prob = model.predict(val_visual)
val_pred_labels = [1 if n >= 0.5 else 0 for n in val_pred_prob]

print("Model predictions: "+str(val_pred_labels))
print("Actual labels:     "+str(val_true_labels))

num_misclasssified = 0
misclassified_filepaths = []
correctness = []
for pred_label, true_label, dir_index in zip(val_pred_labels, val_true_labels, val_visual.index_array):
  misclassified_filepaths.append(val_visual.filepaths[dir_index])
  if pred_label != true_label:
    correctness.append('incorrect')
    num_misclasssified += 1
  else:
    correctness.append('correct')

print("# of total images: "+str(len(correctness)))
print("# of misclassified images: "+str(num_misclasssified))

# %%
misclassified_imgs = []
for filepath in misclassified_filepaths:
  misclassified_imgs.append(mpimg.imread(filepath))

f, axarr = plt.subplots(6,5, figsize=(20,10), constrained_layout=True)  
count = 0
for r in range(6):
  for c in range(5):
    axarr[r,c].imshow(misclassified_imgs[count])
    if correctness[count] == 'correct':
      axarr[r,c].set_title(correctness[count])
    else:
      axarr[r,c].set_title(correctness[count], color='red')
    axarr[r,c].set_axis_off()
    count += 1 
plt.show()

# %%
loss, acc = model.evaluate(validation_generator, verbose=1)
print("Accuracy using evaluate: "+str(acc))
print("Loss using evaluate: "+str(loss))

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

matrix = confusion_matrix(val_true_labels, val_pred_labels, labels=[0, 1])
print('Confusion matrix : \n',matrix, '\n')

tp, fn, fp, tn = confusion_matrix(val_true_labels, val_pred_labels, labels=[1,0]).reshape(-1)
print('Outcome values : \n', tp, fn, fp, tn, '\n')

matrix = classification_report(val_true_labels, val_pred_labels, labels=[1,0])
print('Classification report : \n',matrix)

# %%
val_visual = val_datagen.flow_from_directory(
        validation_dir,
        target_size=(150, 150),
        class_mode='binary',
        shuffle=True)

print(val_visual.class_indices)

# %%
val_pred_prob = model.predict(val_visual)

# %%
val_dir_indices = val_visual.index_array
val_true_labels = [0 if n < 1112 else 1 for n in val_dir_indices] 

val_pred_prob = model.predict(val_visual)

val_pred_labels = [1 if n >= 0.5 else 0 for n in val_pred_prob]

print("Model predictions: "+str(val_pred_labels))
print("Actual labels:     "+str(val_true_labels))

num_misclasssified = 0
misclassified_filepaths = []
correctness = []
for pred_label, true_label, dir_index in zip(val_pred_labels, val_true_labels, val_visual.index_array):
  misclassified_filepaths.append(val_visual.filepaths[dir_index])
  if pred_label != true_label:
    correctness.append('incorrect')
    num_misclasssified += 1
  else:
    correctness.append('correct')

print("# of total images: "+str(len(correctness)))
print("# of misclassified images: "+str(num_misclasssified))

# %%
misclassified_imgs = []
for filepath in misclassified_filepaths:
  misclassified_imgs.append(mpimg.imread(filepath))

# plots first 30 images
f, axarr = plt.subplots(6,5, figsize=(20,10), constrained_layout=True)  # plt.subplots(row,cols)
count = 0
for r in range(6):
  for c in range(5):
    axarr[r,c].imshow(misclassified_imgs[count])
    if correctness[count] == 'correct':
      axarr[r,c].set_title(correctness[count])
    else:
      axarr[r,c].set_title(correctness[count], color='red')
    axarr[r,c].set_axis_off()
    count += 1 
plt.show()

# %%
loss, acc = model.evaluate(validation_generator, verbose=1)
print("Accuracy using evaluate: "+str(acc))
print("Loss using evaluate: "+str(loss))

# %%
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image

def predict_waste_type(image_path):
    model = load_model('trained_model.h5')

    img = image.load_img(image_path, target_size=(150, 150))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0) / 255.0

    prediction = model.predict(img_array)
    if prediction[0][0] < 0.5:
        return "Organic Waste"
    else:
        return "Recyclable Waste"

# %%
model.save('trained_model.h5')

# %%
# !jupyter nbconvert --to script model_classification.ipynb
